# %%
<iframe id="exampleIframe" src="https://example.com" name="exampleFrame"></iframe>

# %%
driver.switch_to.frame("exampleFrame")
driver.switch_to.frame(0)  # Index starts from 0

button = driver.find_element_by_id("submitButton")
button.click()

driver.switch_to.default_content()
